# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing
import seaborn as sns

# %%
comp = pd.read_csv("Company_Data.csv")
comp.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
comp.shape
# Out:
# (400, 11)

# %%
comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
comp.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
comp[comp.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Sales, CompPrice, Income, Advertising, Population, Price, ShelveLoc, Age, Education, Urban, US]
# Index: []

# %%
plt.figure(figsize=(16,9))
sns.heatmap(comp.corr(),annot=True,cmap="BuPu")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12072\3318644019.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(comp.corr(),annot=True,cmap="BuPu")

# %%
g = sns.PairGrid(comp)
g.map_upper(sns.scatterplot,color='red')
g.map_lower(sns.scatterplot, color='green')
g.map_diag(plt.hist)
plt.show()

# %%
comp1 = pd.get_dummies(comp)
comp1
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
#      ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# 0                1               0                 0         0          1
# 1                0               1                 0         0          1
# 2                0               0                 1         0          1
# 3                0               0                 1         0          1
# 4                1               0                 0         0          1
# ..             ...             ...               ...       ...        ...
# 395              0               1                 0         0          1
# 396              0               0                 1         1          0
# 397              0               0                 1         0          1
# 398              1               0                 0         0          1
# 399              0               1                 0         0          1
#
#      US_No  US_Yes
# 0        0       1
# 1        0       1
# 2        0       1
# 3        0       1
# 4        1       0
# ..     ...     ...
# 395      0       1
# 396      0       1
# 397      0       1
# 398      0       1
# 399      0       1
#
# [400 rows x 15 columns]

# %%
#### Since company is interested to know about the segment or attributes causes high sale. 
comp1['Category'] = pd.cut(comp1['Sales'], 
                        bins=[0,10,np.inf], 
                        labels=['Low/Mid','High'],
                       include_lowest=True)
comp1
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
#      ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# 0                1               0                 0         0          1
# 1                0               1                 0         0          1
# 2                0               0                 1         0          1
# 3                0               0                 1         0          1
# 4                1               0                 0         0          1
# ..             ...             ...               ...       ...        ...
# 395              0               1                 0         0          1
# 396              0               0                 1         1          0
# 397              0               0                 1         0          1
# 398              1               0                 0         0          1
# 399              0               1                 0         0          1
#
#      US_No  US_Yes Category
# 0        0       1  Low/Mid
# 1        0       1     High
# 2        0       1     High
# 3        0       1  Low/Mid
# 4        1       0  Low/Mid
# ..     ...     ...      ...
# 395      0       1     High
# 396      0       1  Low/Mid
# 397      0       1  Low/Mid
# 398      0       1  Low/Mid
# 399      0       1  Low/Mid
#
# [400 rows x 16 columns]

# %%
# the applied category here is Y variable and rest all are X variables, hence applying the LableEncoding to Y.
label_encoder=preprocessing.LabelEncoder()
comp1['Category']=label_encoder.fit_transform(comp1['Category'])

# %%
X=comp1.iloc[:,1:15]
Y=comp1.iloc[:,15]

# %%
### Now spliting our data into training and testing data set
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=40)

# %%
### Buliding Descion tree
model=DecisionTreeClassifier(criterion='entropy',max_depth=5)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
### Ploting Tree
tree.plot_tree(model);

# %%
fn=['CompPrice','Income','Advertising','Population','Price','Age','Education',
    'ShelveLoc_Bad','ShelveLoc_Good','ShelveLoc_Medium','Urban_No','Urban_Yes','US_No','US_Yes']
cn=['Low/Mid', 'High']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (6,6), dpi=900)
tree.plot_tree(model,
               feature_names = fn, 
               class_names=cn,
               filled = True);
plt.title('Decision tree using Entropy Criteria',fontsize=5)
# Out:
# Text(0.5, 1.0, 'Decision tree using Entropy Criteria')

# %%
#Predicting on test data
preds = model.predict(x_test) # predicting on test data set

# %%
pd.Series(preds).value_counts() # getting the count of each category
# Out:
# 1    63
# 0    17
# dtype: int64

# %%
pd.crosstab(y_test,preds)## geting 2 way table
# Out:
# col_0     0   1
# Category
# 0         9   5
# 1         8  58

# %%
### Accuracy
np.mean(preds==y_test)
# Out:
# 0.8375

# %%
from sklearn.tree import DecisionTreeClassifier
model_gini = DecisionTreeClassifier(criterion='gini', max_depth=5)

# %%
model_gini.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
fn=['CompPrice','Income','Advertising','Population','Price','Age','Education',
    'ShelveLoc_Bad','ShelveLoc_Good','ShelveLoc_Medium','Urban_No','Urban_Yes','US_No','US_Yes']
cn=['Low/Mid', 'High']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (6,6), dpi=900)
tree.plot_tree(model_gini,
               feature_names = fn, 
               class_names=cn,
               filled = True);
plt.title('Decision tree using GINI',fontsize=5)
# Out:
# Text(0.5, 1.0, 'Decision tree using GINI')

# %%
#Prediction and computing the accuracy
pred=model_gini.predict(x_test)
np.mean(preds==y_test)
# Out:
# 0.8375

# %%
# By seeing Both the Decision tree we can say that "Shelf Location at stores,Pricing,Advertising" are
# top factors affecting the cloth manufacturing company sales
